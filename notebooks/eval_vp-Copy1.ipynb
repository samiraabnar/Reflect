# %%
import os
import tensorflow as tf
from util import constants
from util.config_util import get_model_params, get_task_params, get_train_params
from tf2_models.trainer import Trainer
from absl import app
from absl import flags
import numpy as np
from util.models import MODELS
from util.tasks import TASKS
from notebook_utils import *

# %matplotlib inline
import pandas as pd
import seaborn as sns; sns.set()

from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to /home/dehghani/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
task_name = 'word_sv_agreement_vp'
task = TASKS[task_name](get_task_params(), data_dir='../data')
cl_token = task.databuilder.sentence_encoder().encode(constants.bos)
# Out:
# Vocab len:  10032

# %%
config={'student_exp_name':'lisa_fd131',
    'teacher_exp_name':'0.001_samira_offlineteacher_v11',
    'teacher_config':'small_lstm_v4',
    'task_name':'word_sv_agreement_vp',
    'student_model':'cl_lstm',
    'teacher_model':'cl_lstm',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
       }

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
get_teacher_model(config, task, tchr_hparams, cl_token)
# Out:
# model config: small_lstm_v4
# model config: small_lstm_v4
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_crs_slw_teacher_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_0.001_samira_offlineteacher_v11_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_lisa_fd131
# No checkpoint found ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_crs_slw_teacher_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_0.001_samira_offlineteacher_v11_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_lisa_fd131
# model config: small_lstm_v4
# No checkpoint found ../tf_ckpts/word_sv_agreement_vp/cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_0.001_samira_offlineteacher_v11
# (<tf2_models.lm_lstm.ClassifierLSTM at 0x7fcba8012d90>,
#  <tensorflow.python.training.tracking.util.Checkpoint at 0x7fcba8108750>)

# %%
teacher_model.compile(loss=task.get_loss_fn(), metrics=task.metrics())
train = teacher_model.evaluate(task.train_dataset, steps=task.n_train_batches)
valid = teacher_model.evaluate(task.valid_dataset, steps=task.n_valid_batches)
test = teacher_model.evaluate(task.test_dataset, steps=task.n_test_batches)

print("train:", train)
print("valid:", valid)
print("test:", test)

# %%
train = student_model.evaluate(task.train_dataset, steps=task.n_train_batches)
valid = student_model.evaluate(task.valid_dataset, steps=task.n_valid_batches)
test = student_model.evaluate(task.test_dataset, steps=task.n_test_batches)

print("train:", train)
print("valid:", valid)
print("test:", test)

# %%
student_models = []
student_labels = []

import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
config={'student_exp_name':'gc_f_std157',
    'teacher_exp_name':'gc_o_tchr157',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }

config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2lstm_157')

config={'student_exp_name':'gc_f_std158',
    'teacher_exp_name':'gc_o_tchr158',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }

config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2lstm_158')

config={'student_exp_name':'gc_f_std159',
    'teacher_exp_name':'gc_o_tchr159',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }


config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2lstm_159')

config={'student_exp_name':'gc_f_std160',
    'teacher_exp_name':'gc_o_tchr160',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }

config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2lstm_1')
# Out:
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr157_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std157
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr157_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std157/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr157/ckpt-60
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr158_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std158
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr158_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std158/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr158/ckpt-60
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr159_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std159
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr159_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std159/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr159/ckpt-60
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr160_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std160
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr160_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_o_std160/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr160/ckpt-60

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
# student_models = []
# student_labels = []

config={'student_exp_name':'gc_f_std155',
    'teacher_exp_name':'gc_o_tchr155',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2ugpt_155')

config={'student_exp_name':'gc_f_std156',
    'teacher_exp_name':'gc_o_tchr156',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2ugpt_156')

config={'student_exp_name':'gc_f_std153',
    'teacher_exp_name':'gc_o_tchr153',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')


std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2ugpt_153')

config={'student_exp_name':'gc_f_std154',
    'teacher_exp_name':'gc_o_tchr154',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2ugpt_154')
# Out:
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr155_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std155
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr155_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std155/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr155/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr156_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std156
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr156_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std156/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr156/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr153_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std153
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr153_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std153/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr153/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr154_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std154
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr154_student_cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std154/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr154/ckpt-60

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    
    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
# student_models = []
# student_labels = []

config={'student_exp_name':'gc_f_std176',
    'teacher_exp_name':'gc_o_tchr176',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2bert_176')

config={'student_exp_name':'gc_f_std173',
    'teacher_exp_name':'gc_o_tchr173',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2bert_173')

config={'student_exp_name':'gc_f_std174',
    'teacher_exp_name':'gc_o_tchr174',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2bert_174')

config={'student_exp_name':'gc_f_std175',
    'teacher_exp_name':'gc_o_tchr175',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2bert_175')
# Out:
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr176_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std176
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr176_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std176/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr176/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr173_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std173
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr173_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std173/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr173/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr174_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std174
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr174_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std174/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr174/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr175_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std175
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr175_student_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std175/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr175/ckpt-60

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
# student_models = []
# student_labels = []

config={'student_exp_name':'gc_f_std161',
    'teacher_exp_name':'gc_o_tchr161',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)


student_models.append(student_model)
student_labels.append('gpt2gpt_161')

config={'student_exp_name':'gc_f_std162',
    'teacher_exp_name':'gc_o_tchr162',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')
std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2gpt_162')

config={'student_exp_name':'gc_f_std164',
    'teacher_exp_name':'gc_o_tchr164',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')
std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2gpt_164')

config={'student_exp_name':'gc_f_std163',
    'teacher_exp_name':'gc_o_tchr163',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')
std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('gpt2gpt_163')
# Out:
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr161_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std161
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr161_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std161/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr161/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr162_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std162
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr162_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std162/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr162/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr164_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std164
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr164_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std164/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr164/ckpt-60
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr163_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std163
# Restored student from ../tf_ckpts/word_sv_agreement_vp/online_pure_dstl_4_crs_slw_teacher_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr163_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_std163/ckpt-60
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr163/ckpt-60

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
# student_models = []
# student_labels = []

config={'student_exp_name':'gc_f_std116',
    'teacher_exp_name':'gc_o_tchr116',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ubert_116')

config={'student_exp_name':'gc_f_std117',
    'teacher_exp_name':'gc_o_tchr117',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')
std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ubert_117')

config={'student_exp_name':'gc_f_std118',
    'teacher_exp_name':'gc_o_tchr118',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')
std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ubert_118')

config={'student_exp_name':'gc_f_std119',
    'teacher_exp_name':'gc_o_tchr119',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
config['distill_mode'] = 'online'
config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')
std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ubert_119')

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
import tensorflow_probability as tfp

def test_for_calibration(model, task, n_bins=10):
    preds = []
    correct_class_probs = []
    predicted_class_probs = []
    pred_logits = []
    y_trues = []
    batch_count = task.n_valid_batches
    for x, y in task.valid_dataset:
        y = tf.cast(y, tf.int32)
        logits = model(x)
        pred_logits.extend(logits.numpy())
        pred = tf.argmax(logits, axis=-1)
        prob = task.get_probs_fn()(logits, labels=y, temperature=1)
        preds.extend(pred.numpy())
        y_trues.extend(y.numpy())
        batch_indexes = tf.cast(tf.range(len(y), dtype=tf.int32), dtype=tf.int32)
        true_indexes = tf.concat([batch_indexes[:,None], y[:,None]], axis=1)
        pred_indexes = tf.concat([batch_indexes[:,None], tf.cast(pred[:,None], tf.int32)], axis=1)

        correct_class_probs.extend(tf.gather_nd(prob, true_indexes).numpy())
        predicted_class_probs.extend(tf.gather_nd(prob, pred_indexes).numpy())

        batch_count -= 1
        if batch_count == 0:
            break

    model_accuracy = np.asarray(preds) == np.asarray(y_trues)

    return model_accuracy, predicted_class_probs, correct_class_probs, pred_logits, y_trues


for label,model in zip(student_labels, student_models):
    print(label)
    print(model.model_name)

    model_accuracy, predicted_class_probs, correct_class_probs, model_logits, model_trues= test_for_calibration(model, task, n_bins=20)

    #print(len(model_accuracy))
    #print(len(predicted_class_probs))
    ##plot_calibration(model_accuracy, predicted_class_probs, correct_class_probs, n_bins=20)
    #  plt.show()
    model_ece = tfp.stats.expected_calibration_error(
        1000000,
        logits=model_logits,
        labels_true=model_trues,
    )
    print(model_ece.numpy())
    
    print("#######################")
# Out:
# gpt2lstm_157
# cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2
# 0.041223407
# #######################
# gpt2lstm_158
# cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2
# 0.040874265
# #######################
# gpt2lstm_159
# cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2
# 0.039741464
# #######################
# gpt2lstm_1
# cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2
# 0.040254436
# #######################
# gpt2ugpt_155
# cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.04419593
# #######################
# gpt2ugpt_156
# cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.045162655
# #######################
# gpt2ugpt_153
# cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.045108337
# #######################
# gpt2ugpt_154
# cl_gpt2_shared_weights_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.044366114
# #######################
# gpt2bert_176
# cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.05723703
# #######################
# gpt2bert_173
# cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.055468593
# #######################
# gpt2bert_174
# cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.053293176
# #######################
# gpt2bert_175
# cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.054846574
# #######################
# gpt2gpt_161
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.04435677
# #######################
# gpt2gpt_162
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.04620939
# #######################
# gpt2gpt_164
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.04338689
# #######################
# gpt2gpt_163
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.0444365
# #######################
