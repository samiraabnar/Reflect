# %%
import os
import tensorflow as tf
from util import constants
from util.config_util import get_model_params, get_task_params, get_train_params
from tf2_models.trainer import Trainer
from absl import app
from absl import flags
import numpy as np
from util.models import MODELS
from util.tasks import TASKS
from notebook_utils import *

# %matplotlib inline
import pandas as pd
import seaborn as sns; sns.set()

from tqdm import tqdm

import logging
tf.get_logger().setLevel(logging.ERROR)
# Out:
# [nltk_data] Downloading package punkt to /home/dehghani/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
task_name = 'word_sv_agreement_vp'
task = TASKS[task_name](get_task_params(), data_dir='../data')
cl_token = task.databuilder.sentence_encoder().encode(constants.bos)
# Out:
# Vocab len:  10032

# %%
config={'student_exp_name':'lisa_fd131',
    'teacher_exp_name':'0.001_samira_offlineteacher_v11',
    'teacher_config':'small_lstm_v4',
    'task_name':'word_sv_agreement_vp',
    'student_model':'cl_lstm',
    'teacher_model':'cl_lstm',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_crs_slw',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
       }

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
get_teacher_model(config, task, tchr_hparams, cl_token)

# %%
teacher_model.compile(loss=task.get_loss_fn(), metrics=task.metrics())
train = teacher_model.evaluate(task.train_dataset, steps=task.n_train_batches)
valid = teacher_model.evaluate(task.valid_dataset, steps=task.n_valid_batches)
test = teacher_model.evaluate(task.test_dataset, steps=task.n_test_batches)

print("train:", train)
print("valid:", valid)
print("test:", test)

# %%
train = student_model.evaluate(task.train_dataset, steps=task.n_train_batches)
valid = student_model.evaluate(task.valid_dataset, steps=task.n_valid_batches)
test = student_model.evaluate(task.test_dataset, steps=task.n_test_batches)

print("train:", train)
print("valid:", valid)
print("test:", test)

# %%
student_models = []
student_labels = []

import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
#Bert to LSTM

config={'student_exp_name':'gc_f_std9303',
    'teacher_exp_name':'gc_o_tchr8323',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_exp_vp9',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }

# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2lstm_1')

config={'student_exp_name':'gc_f_std9304',
    'teacher_exp_name':'gc_o_tchr8324',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_exp_vp9',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }

# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2lstm_2')

config={'student_exp_name':'gc_f_std9301',
    'teacher_exp_name':'gc_o_tchr9301',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_exp_vp9',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }


# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2lstm_3')

config={'student_exp_name':'gc_f_std9302',
    'teacher_exp_name':'gc_o_tchr9302',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_lstm',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_exp_vp9',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }

# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2lstm_4')
# Out:
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9303
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9303/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323/ckpt-40
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9304
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9304/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324/ckpt-40
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr9301_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9301
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr9301_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9301/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr9301/ckpt-40
# model config: small_lstm_v4
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr9302_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9302
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp9_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr9302_student_cl_lstm_em-256_h-256_d-2_hdrop-0.8_indrop-0.2_small_lstm_v4_gc_f_std9302/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr9302/ckpt-40

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)
# Out:
# 2464/2464 [==============================] - 113s 46ms/step - loss: 0.1137 - classification_loss: 0.0700 - sparse_categorical_accuracy: 0.9730
# 246/246 [==============================] - 11s 46ms/step - loss: 0.1253 - classification_loss: 0.0816 - sparse_categorical_accuracy: 0.9682
# 21933/21933 [==============================] - 929s 42ms/step - loss: 0.1246 - classification_loss: 0.0809 - sparse_categorical_accuracy: 0.9682
# bert2lstm_1
# train: [0.11367774988198048, 0.06996991, 0.97296697]
# valid: [0.12534940089818422, 0.08164158, 0.9682419]
# test: [0.12462983588440818, 0.08092227, 0.9682079]
# 2464/2464 [==============================] - 107s 43ms/step - loss: 0.1139 - classification_loss: 0.0705 - sparse_categorical_accuracy: 0.9731
# 246/246 [==============================] - 11s 43ms/step - loss: 0.1265 - classification_loss: 0.0832 - sparse_categorical_accuracy: 0.9681
# 21933/21933 [==============================] - 934s 43ms/step - loss: 0.1255 - classification_loss: 0.0822 - sparse_categorical_accuracy: 0.9684
# bert2lstm_2
# train: [0.11388663106670531, 0.070547186, 0.9730938]
# valid: [0.12651636230388308, 0.08317699, 0.9680513]
# test: [0.12551573746938013, 0.082176335, 0.96841586]
# 2464/2464 [==============================] - 105s 42ms/step - loss: 0.1147 - classification_loss: 0.0708 - sparse_categorical_accuracy: 0.9726
# 246/246 [==============================] - 11s 43ms/step - loss: 0.1261 - classification_loss: 0.0822 - sparse_categorical_accuracy: 0.9683
# 21933/21933 [==============================] - 928s 42ms/step - loss: 0.1254 - classification_loss: 0.0814 - sparse_categorical_accuracy: 0.9681
# bert2lstm_3
# train: [0.11469655483809917, 0.07076991, 0.97262454]
# valid: [0.12609232925787206, 0.08216571, 0.9683054]
# test: [0.1253685245549163, 0.08144198, 0.96807534]
# 2464/2464 [==============================] - 105s 43ms/step - loss: 0.1137 - classification_loss: 0.0703 - sparse_categorical_accuracy: 0.9732
# 246/246 [==============================] - 11s 43ms/step - loss: 0.1258 - classification_loss: 0.0824 - sparse_categorical_accuracy: 0.9684
# 21933/21933 [==============================] - 928s 42ms/step - loss: 0.1248 - classification_loss: 0.0814 - sparse_categorical_accuracy: 0.9683
# bert2lstm_4
# train: [0.11365238755681346, 0.070286274, 0.9731572]
# valid: [0.1257984259930568, 0.082432374, 0.9683689]
# test: [0.12475644688944085, 0.08139042, 0.9683154]

# %%
student_models = []
student_labels = []

config={'student_exp_name':'gc_f_std8331',
    'teacher_exp_name':'gc_o_tchr8321',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ugpt_1')

config={'student_exp_name':'gc_f_std8332',
    'teacher_exp_name':'gc_o_tchr8322',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ugpt_2')

config={'student_exp_name':'gc_f_std8333',
    'teacher_exp_name':'gc_o_tchr8323',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')


std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ugpt_3')

config={'student_exp_name':'gc_f_std8334',
    'teacher_exp_name':'gc_o_tchr8324',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2ugpt_4')
# Out:
# model config: small_ugpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8321_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8331
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8321_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8331/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8321/ckpt-40
# model config: small_ugpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8322_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8332
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8322_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8332/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8322/ckpt-40
# model config: small_ugpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8333
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8333/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323/ckpt-40
# model config: small_ugpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8334
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324_student_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_f_std8334/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324/ckpt-40

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    
    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)
# Out:
# 2464/2464 [==============================] - 29s 12ms/step - loss: 0.0849 - classification_loss: 0.0743 - sparse_categorical_accuracy: 0.9710
# 246/246 [==============================] - 3s 11ms/step - loss: 0.1113 - classification_loss: 0.1006 - sparse_categorical_accuracy: 0.9601
# 21933/21933 [==============================] - 254s 12ms/step - loss: 0.1108 - classification_loss: 0.1001 - sparse_categorical_accuracy: 0.9604
# bert2ugpt_1
# train: [0.08494035557574629, 0.074250884, 0.97103286]
# valid: [0.1113257008809142, 0.10063622, 0.9601118]
# test: [0.11076045492495405, 0.100070916, 0.96042424]
# 2464/2464 [==============================] - 31s 13ms/step - loss: 0.0819 - classification_loss: 0.0707 - sparse_categorical_accuracy: 0.9723
# 246/246 [==============================] - 3s 12ms/step - loss: 0.1062 - classification_loss: 0.0951 - sparse_categorical_accuracy: 0.9623
# 21933/21933 [==============================] - 257s 12ms/step - loss: 0.1069 - classification_loss: 0.0958 - sparse_categorical_accuracy: 0.9617
# bert2ugpt_2
# train: [0.08189922259053119, 0.0707205, 0.9723138]
# valid: [0.10623217220380296, 0.09505337, 0.9623349]
# test: [0.10693008809429454, 0.09575116, 0.96170294]
# 2464/2464 [==============================] - 31s 13ms/step - loss: 0.0830 - classification_loss: 0.0720 - sparse_categorical_accuracy: 0.9718
# 246/246 [==============================] - 3s 12ms/step - loss: 0.1073 - classification_loss: 0.0963 - sparse_categorical_accuracy: 0.9632
# 21933/21933 [==============================] - 257s 12ms/step - loss: 0.1074 - classification_loss: 0.0963 - sparse_categorical_accuracy: 0.9614
# bert2ugpt_3
# train: [0.08297739603387361, 0.07195256, 0.97180015]
# valid: [0.10734990025620635, 0.096325174, 0.9632241]
# test: [0.10735201485183618, 0.09632752, 0.9614038]
# 2464/2464 [==============================] - 31s 13ms/step - loss: 0.0826 - classification_loss: 0.0715 - sparse_categorical_accuracy: 0.9721
# 246/246 [==============================] - 3s 12ms/step - loss: 0.1097 - classification_loss: 0.0987 - sparse_categorical_accuracy: 0.9613
# 21933/21933 [==============================] - 255s 12ms/step - loss: 0.1088 - classification_loss: 0.0977 - sparse_categorical_accuracy: 0.9610
# bert2ugpt_4
# train: [0.08259327491055932, 0.07151207, 0.97211725]
# valid: [0.10973802378507165, 0.09865693, 0.9613186]
# test: [0.10881579560991798, 0.09773467, 0.96101123]

# %%
student_models = []
student_labels = []

config={'student_exp_name':'gc_f_std8311',
    'teacher_exp_name':'gc_o_tchr8311',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2bert_1')

config={'student_exp_name':'gc_f_std8312',
    'teacher_exp_name':'gc_o_tchr8322',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2bert_2')

config={'student_exp_name':'gc_f_std8313',
    'teacher_exp_name':'gc_o_tchr8323',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2bert_3')

config={'student_exp_name':'gc_f_std8314',
    'teacher_exp_name':'gc_o_tchr8324',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_bert',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2bert_4')

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
student_models = []
student_labels = []

config={'student_exp_name':'gc_f_std8321',
    'teacher_exp_name':'gc_o_tchr8321',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2gpt_1')

config={'student_exp_name':'gc_f_std8322',
    'teacher_exp_name':'gc_o_tchr8322',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2gpt_2')

config={'student_exp_name':'gc_f_std8323',
    'teacher_exp_name':'gc_o_tchr8323',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')


std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2gpt_3')

config={'student_exp_name':'gc_f_std8324',
    'teacher_exp_name':'gc_o_tchr8324',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_bert',
    'student_model':'cl_gpt2',
    'teacher_config':'small_gpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp8',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('bert2gpt_4')
# Out:
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8321_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8321
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8321_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8321/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8321/ckpt-40
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8322_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8322
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8322_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8322/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8322/ckpt-40
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8323
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8323/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8323/ckpt-40
# model config: small_gpt_v9
# model config: small_gpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8324
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp8_teacher_cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std8324/ckpt-40
# model config: small_gpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_bert_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_o_tchr8324/ckpt-40

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)
# Out:
# 2464/2464 [==============================] - 29s 12ms/step - loss: 0.0861 - classification_loss: 0.0756 - sparse_categorical_accuracy: 0.9701
# 246/246 [==============================] - 3s 11ms/step - loss: 0.1166 - classification_loss: 0.1061 - sparse_categorical_accuracy: 0.9587
# 21933/21933 [==============================] - 237s 11ms/step - loss: 0.1167 - classification_loss: 0.1062 - sparse_categorical_accuracy: 0.9584
# bert2gpt_1
# train: [0.08605750632100412, 0.075574756, 0.9700944]
# valid: [0.11661282438421394, 0.10613023, 0.9587144]
# test: [0.11667159078693255, 0.106189385, 0.95841384]
# 2464/2464 [==============================] - 29s 12ms/step - loss: 0.0834 - classification_loss: 0.0724 - sparse_categorical_accuracy: 0.9717
# 246/246 [==============================] - 3s 11ms/step - loss: 0.1102 - classification_loss: 0.0993 - sparse_categorical_accuracy: 0.9614
# 21933/21933 [==============================] - 238s 11ms/step - loss: 0.1103 - classification_loss: 0.0993 - sparse_categorical_accuracy: 0.9606
# bert2gpt_2
# train: [0.08338424784634807, 0.07244582, 0.9717304]
# valid: [0.11020044706822411, 0.09926206, 0.9613821]
# test: [0.11025189760783145, 0.09931357, 0.96056527]
# 2464/2464 [==============================] - 29s 12ms/step - loss: 0.0844 - classification_loss: 0.0734 - sparse_categorical_accuracy: 0.9713
# 246/246 [==============================] - 3s 11ms/step - loss: 0.1147 - classification_loss: 0.1037 - sparse_categorical_accuracy: 0.9607
# 21933/21933 [==============================] - 234s 11ms/step - loss: 0.1137 - classification_loss: 0.1027 - sparse_categorical_accuracy: 0.9593
# bert2gpt_3
# train: [0.08443191509872264, 0.07338678, 0.97133726]
# valid: [0.11471713105655783, 0.10367197, 0.9606834]
# test: [0.11373966158321962, 0.10269478, 0.9593407]
# 2464/2464 [==============================] - 29s 12ms/step - loss: 0.0833 - classification_loss: 0.0726 - sparse_categorical_accuracy: 0.9716
# 246/246 [==============================] - 3s 11ms/step - loss: 0.1102 - classification_loss: 0.0994 - sparse_categorical_accuracy: 0.9613
# 21933/21933 [==============================] - 236s 11ms/step - loss: 0.1122 - classification_loss: 0.1014 - sparse_categorical_accuracy: 0.9599
# bert2gpt_4
# train: [0.08334413391852437, 0.072577566, 0.97159094]
# valid: [0.11016246544696935, 0.099395886, 0.9613186]
# test: [0.11219475881633877, 0.10142843, 0.9599277]

# %%
import tensorflow_probability as tfp

def test_for_calibration(model, task, n_bins=10):
    preds = []
    correct_class_probs = []
    predicted_class_probs = []
    pred_logits = []
    y_trues = []
    batch_count = task.n_valid_batches
    for x, y in task.valid_dataset:
        y = tf.cast(y, tf.int32)
        logits = model(x)
        pred_logits.extend(logits.numpy())
        pred = tf.argmax(logits, axis=-1)
        prob = task.get_probs_fn()(logits, labels=y, temperature=1)
        preds.extend(pred.numpy())
        y_trues.extend(y.numpy())
        batch_indexes = tf.cast(tf.range(len(y), dtype=tf.int32), dtype=tf.int32)
        true_indexes = tf.concat([batch_indexes[:,None], y[:,None]], axis=1)
        pred_indexes = tf.concat([batch_indexes[:,None], tf.cast(pred[:,None], tf.int32)], axis=1)

        correct_class_probs.extend(tf.gather_nd(prob, true_indexes).numpy())
        predicted_class_probs.extend(tf.gather_nd(prob, pred_indexes).numpy())

        batch_count -= 1
        if batch_count == 0:
            break

    model_accuracy = np.asarray(preds) == np.asarray(y_trues)

    return model_accuracy, predicted_class_probs, correct_class_probs, pred_logits, y_trues


for label,model in zip(student_labels, student_models):
    print(label)
    print(model.model_name)

    model_accuracy, predicted_class_probs, correct_class_probs, model_logits, model_trues= test_for_calibration(model, task, n_bins=20)

    #print(len(model_accuracy))
    #print(len(predicted_class_probs))
    ##plot_calibration(model_accuracy, predicted_class_probs, correct_class_probs, n_bins=20)
    #  plt.show()
    model_ece = tfp.stats.expected_calibration_error(
        1000000,
        logits=model_logits,
        labels_true=model_trues,
    )
    print(model_ece.numpy())
    
    print("#######################")
# Out:
# bert2gpt_1
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.052904233
# #######################
# bert2gpt_2
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.053746067
# #######################
# bert2gpt_3
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.054164797
# #######################
# bert2gpt_4
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
