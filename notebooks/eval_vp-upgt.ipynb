# %%
import os
import tensorflow as tf
from util import constants
from util.config_util import get_model_params, get_task_params, get_train_params
from tf2_models.trainer import Trainer
from absl import app
from absl import flags
import numpy as np
from util.models import MODELS
from util.tasks import TASKS
from notebook_utils import *

# %matplotlib inline
import pandas as pd
import seaborn as sns; sns.set()

from tqdm import tqdm
# Out:
# [nltk_data] Downloading package punkt to /home/dehghani/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
task_name = 'word_sv_agreement_vp'
task = TASKS[task_name](get_task_params(), data_dir='../data')
cl_token = task.databuilder.sentence_encoder().encode(constants.bos)
# Out:
# Vocab len:  10032

# %%
student_models = []
student_labels = []

import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
# config={'student_exp_name':'gc_f_std4104',
#     'teacher_exp_name':'gc_o_tchr4112',
#     'task_name':'word_sv_agreement_vp',
#     'teacher_model':'cl_gpt2_shared',
#     'student_model':'cl_lstm',
#     'teacher_config':'small_ugpt_v9',
#     'student_config':'small_lstm_v4',
#     'distill_config':'pure_dstl_4_exp_vp4',
#     'distill_mode':'offline',
#     'chkpt_dir':'../tf_ckpts',
#      }

# # config['distill_mode'] = 'online'
# # config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

# std_hparams=get_model_params(task, config['student_model'], config['student_config'])
# std_hparams.output_attentions = True
# std_hparams.output_embeddings = True

# student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

# tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
# teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

# student_models.append(student_model)
# student_labels.append('ugpt2lstm_1')

# config={'student_exp_name':'gc_f_std4103',
#     'teacher_exp_name':'gc_o_tchr4113',
#     'task_name':'word_sv_agreement_vp',
#     'teacher_model':'cl_gpt2_shared',
#     'student_model':'cl_lstm',
#     'teacher_config':'small_ugpt_v9',
#     'student_config':'small_lstm_v4',
#     'distill_config':'pure_dstl_4_exp_vp4',
#     'distill_mode':'offline',
#     'chkpt_dir':'../tf_ckpts',
#      }

# # config['distill_mode'] = 'online'
# # config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

# std_hparams=get_model_params(task, config['student_model'], config['student_config'])
# std_hparams.output_attentions = True
# std_hparams.output_embeddings = True

# student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

# tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
# teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

# student_models.append(student_model)
# student_labels.append('ugpt2lstm_2')

# config={'student_exp_name':'gc_f_std4102',
#     'teacher_exp_name':'gc_o_tchr4102',
#     'task_name':'word_sv_agreement_vp',
#     'teacher_model':'cl_gpt2_shared',
#     'student_model':'cl_lstm',
#     'teacher_config':'small_ugpt_v9',
#     'student_config':'small_lstm_v4',
#     'distill_config':'pure_dstl_4_exp_vp4',
#     'distill_mode':'offline',
#     'chkpt_dir':'../tf_ckpts',
#      }


# # config['distill_mode'] = 'online'
# # config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

# std_hparams=get_model_params(task, config['student_model'], config['student_config'])
# std_hparams.output_attentions = True
# std_hparams.output_embeddings = True

# student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

# tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
# teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

# student_models.append(student_model)
# student_labels.append('ugpt2lstm_3')

config={'student_exp_name':'gc_f_std4101',
    'teacher_exp_name':'gc_o_tch4101',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_lstm',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_lstm_v4',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }

# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2lstm_4')

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
student_models = []
student_labels = []

config={'student_exp_name':'gc_f_std4131',
    'teacher_exp_name':'gc_o_tchr4131',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2ugpt_1')

config={'student_exp_name':'gc_f_std4132',
    'teacher_exp_name':'gc_o_tchr4132',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2ugpt_2')

config={'student_exp_name':'gc_f_std4130',
    'teacher_exp_name':'gc_o_tchr4130',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')


std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2ugpt_3')

config={'student_exp_name':'gc_f_std4133',
    'teacher_exp_name':'gc_o_tchr4123',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2_shared',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_ugpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2ugpt_4')

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    
    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
student_models = []
student_labels = []

config={'student_exp_name':'gc_f_std4110',
    'teacher_exp_name':'gc_o_tchr4110',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_bert',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2bert_1')

config={'student_exp_name':'gc_f_std4111',
    'teacher_exp_name':'gc_o_tchr4111',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_bert',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2bert_2')

config={'student_exp_name':'gc_f_std4112',
    'teacher_exp_name':'gc_o_tchr4112',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_bert',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2bert_3')

config={'student_exp_name':'gc_f_std4113',
    'teacher_exp_name':'gc_o_tchr4113',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_bert',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2bert_4')

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)

# %%
student_models = []
student_labels = []

config={'student_exp_name':'gc_f_std4120',
    'teacher_exp_name':'gc_o_tchr4120',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2gpt_1')

config={'student_exp_name':'gc_f_std4121',
    'teacher_exp_name':'gc_o_tchr4121',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2gpt_2')

config={'student_exp_name':'gc_f_std4122',
    'teacher_exp_name':'gc_o_tchr4122',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')


std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2gpt_3')

config={'student_exp_name':'gc_f_std4123',
    'teacher_exp_name':'gc_o_tchr4123',
    'task_name':'word_sv_agreement_vp',
    'teacher_model':'cl_gpt2_shared',
    'student_model':'cl_gpt2',
    'teacher_config':'small_ugpt_v9',
    'student_config':'small_gpt_v9',
    'distill_config':'pure_dstl_4_exp_vp4',
    'distill_mode':'offline',
    'chkpt_dir':'../tf_ckpts',
     }
# config['distill_mode'] = 'online'
# config['student_exp_name'] = config['student_exp_name'].replace('_f_', '_o_')

std_hparams=get_model_params(task, config['student_model'], config['student_config'])
std_hparams.output_attentions = True
std_hparams.output_embeddings = True

student_model, ckpt = get_student_model(config, task, std_hparams, cl_token)

tchr_hparams=get_model_params(task, config['teacher_model'], config['teacher_config'])
teacher_model = get_teacher_model(config, task, tchr_hparams, cl_token)

student_models.append(student_model)
student_labels.append('ugpt2gpt_4')
# Out:
# model config: small_gpt_v9
# model config: small_ugpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4120_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4120
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4120_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4120/ckpt-40
# model config: small_ugpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4120/ckpt-40
# model config: small_gpt_v9
# model config: small_ugpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4121_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4121
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4121_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4121/ckpt-40
# model config: small_ugpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4121/ckpt-40
# model config: small_gpt_v9
# model config: small_ugpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4122_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4122
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4122_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4122/ckpt-40
# model config: small_ugpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4122/ckpt-40
# model config: small_gpt_v9
# model config: small_ugpt_v9
# student_checkpoint: ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4123_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4123
# Restored student from ../tf_ckpts/word_sv_agreement_vp/offline_pure_dstl_4_exp_vp4_teacher_cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4123_student_cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_gpt_v9_gc_f_std4123/ckpt-40
# model config: small_ugpt_v9
# Restored student from ../tf_ckpts/word_sv_agreement_vp/cl_gpt2_shared_weights_h-256_d-6_rdrop-0.4_adrop-0.6_indrop-0.2_small_ugpt_v9_gc_o_tchr4123/ckpt-40

# %%
for lbl, mdl in zip(student_labels, student_models):
    train = mdl.evaluate(task.train_dataset, steps=task.n_train_batches)
    valid = mdl.evaluate(task.valid_dataset, steps=task.n_valid_batches)
    test = mdl.evaluate(task.test_dataset, steps=task.n_test_batches)

    print(lbl)
    print("train:", train)
    print("valid:", valid)
    print("test:", test)
# Out:
# 2464/2464 [==============================] - 28s 11ms/step - loss: 0.0680 - classification_loss: 0.0552 - sparse_categorical_accuracy: 0.9783
# 246/246 [==============================] - 3s 10ms/step - loss: 0.0937 - classification_loss: 0.0809 - sparse_categorical_accuracy: 0.9686
# 21933/21933 [==============================] - 220s 10ms/step - loss: 0.0937 - classification_loss: 0.0809 - sparse_categorical_accuracy: 0.9682
# ugpt2gpt_1
# train: [0.06795897093668048, 0.05516086, 0.97829366]
# valid: [0.09373498136344237, 0.08093685, 0.96855944]
# test: [0.09373101134653014, 0.08093275, 0.96816087]
# 2464/2464 [==============================] - 26s 11ms/step - loss: 0.0694 - classification_loss: 0.0567 - sparse_categorical_accuracy: 0.9781
# 246/246 [==============================] - 2s 10ms/step - loss: 0.0999 - classification_loss: 0.0872 - sparse_categorical_accuracy: 0.9679
# 21933/21933 [==============================] - 218s 10ms/step - loss: 0.0986 - classification_loss: 0.0859 - sparse_categorical_accuracy: 0.9672
# ugpt2gpt_2
# train: [0.06943902781145501, 0.056730963, 0.9781161]
# valid: [0.09987631285699403, 0.087168284, 0.96786076]
# test: [0.0986041605334308, 0.08589619, 0.96721476]
# 2464/2464 [==============================] - 26s 11ms/step - loss: 0.0694 - classification_loss: 0.0565 - sparse_categorical_accuracy: 0.9777
# 246/246 [==============================] - 2s 10ms/step - loss: 0.0965 - classification_loss: 0.0836 - sparse_categorical_accuracy: 0.9682
# 21933/21933 [==============================] - 217s 10ms/step - loss: 0.0964 - classification_loss: 0.0836 - sparse_categorical_accuracy: 0.9679
# ugpt2gpt_3
# train: [0.06938662907628754, 0.05654649, 0.97774833]
# valid: [0.09646095626995088, 0.08362083, 0.96817833]
# test: [0.09643330382935539, 0.08359335, 0.96789086]
# 2464/2464 [==============================] - 26s 11ms/step - loss: 0.0675 - classification_loss: 0.0545 - sparse_categorical_accuracy: 0.9782
# 246/246 [==============================] - 3s 10ms/step - loss: 0.0965 - classification_loss: 0.0835 - sparse_categorical_accuracy: 0.9681
# 21933/21933 [==============================] - 218s 10ms/step - loss: 0.0948 - classification_loss: 0.0819 - sparse_categorical_accuracy: 0.9682
# ugpt2gpt_4
# train: [0.0674716560778589, 0.054544665, 0.9781859]
# valid: [0.09647388760818214, 0.083546855, 0.9680513]
# test: [0.09483959838018138, 0.081912726, 0.96822995]

# %%
import tensorflow_probability as tfp

def test_for_calibration(model, task, n_bins=10):
    preds = []
    correct_class_probs = []
    predicted_class_probs = []
    pred_logits = []
    y_trues = []
    batch_count = task.n_valid_batches
    for x, y in task.valid_dataset:
        y = tf.cast(y, tf.int32)
        logits = model(x)
        pred_logits.extend(logits.numpy())
        pred = tf.argmax(logits, axis=-1)
        prob = task.get_probs_fn()(logits, labels=y, temperature=1)
        preds.extend(pred.numpy())
        y_trues.extend(y.numpy())
        batch_indexes = tf.cast(tf.range(len(y), dtype=tf.int32), dtype=tf.int32)
        true_indexes = tf.concat([batch_indexes[:,None], y[:,None]], axis=1)
        pred_indexes = tf.concat([batch_indexes[:,None], tf.cast(pred[:,None], tf.int32)], axis=1)

        correct_class_probs.extend(tf.gather_nd(prob, true_indexes).numpy())
        predicted_class_probs.extend(tf.gather_nd(prob, pred_indexes).numpy())

        batch_count -= 1
        if batch_count == 0:
            break

    model_accuracy = np.asarray(preds) == np.asarray(y_trues)

    return model_accuracy, predicted_class_probs, correct_class_probs, pred_logits, y_trues


for label,model in zip(student_labels, student_models):
    print(label)
    print(model.model_name)

    model_accuracy, predicted_class_probs, correct_class_probs, model_logits, model_trues= test_for_calibration(model, task, n_bins=20)

    #print(len(model_accuracy))
    #print(len(predicted_class_probs))
    ##plot_calibration(model_accuracy, predicted_class_probs, correct_class_probs, n_bins=20)
    #  plt.show()
    model_ece = tfp.stats.expected_calibration_error(
        1000000,
        logits=model_logits,
        labels_true=model_trues,
    )
    print(model_ece.numpy())
    
    print("#######################")
# Out:
# ugpt2gpt_1
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.04244214
# #######################
# ugpt2gpt_2
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.042697918
# #######################
# ugpt2gpt_3
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.04239814
# #######################
# ugpt2gpt_4
# cl_gpt2_h-128_d-6_rdrop-0.4_adrop-0.6_indrop-0.2
# 0.0418902
# #######################

# %%
from tqdm import tqdm



def evaluate_vp_cl(model, verb_infl, noun_infl, task, split='test', batch_size=1000, cls=False):
    distance_hits = Counter()
    distance_total = Counter()
    diff_hits = Counter()
    diff_total = Counter()

    test_data = task.databuilder.as_dataset(split=split, batch_size=batch_size)
    e = 0
    for examples in test_data:
        e += 1
        print(e, end="\r")
        sentences = examples['sentence']
        #bos = tf.cast(task.databuilder.sentence_encoder().encode(constants.bos) * tf.ones((sentences.shape[0],1)), dtype=tf.int64)
        eos = tf.cast(task.databuilder.sentence_encoder().encode(constants.eos) *tf.ones((sentences.shape[0],1)), dtype=tf.int64)

        sentences = tf.concat([sentences, eos], axis=-1)

        verb_position = examples['verb_position']+int(cls)  #+1 because of adding bos.
        # The verb it self is also masked
        mask = tf.cast(tf.sequence_mask(verb_position,maxlen=tf.shape(sentences)[1]), dtype=tf.int64)
        max_length = tf.reduce_max(verb_position + 1)

        last_index_mask = tf.gather(tf.eye(tf.shape(sentences)[1], dtype=tf.int64),verb_position)
        last_index_mask = last_index_mask * eos[0]

        inputs = (sentences * mask + last_index_mask)[:,:max_length]

#         print(sentences[0])
#         print(task.databuilder.sentence_encoder().decode(inputs[0]))
#         break
        s_shape = tf.shape(inputs)
        batch_size, length = s_shape[0], s_shape[1]
        verb_classes = examples['verb_class']
        actual_verbs = examples['verb']
        #inflected_verbs = [verb_infl[v.decode("utf-8")] for v in actual_verbs.numpy()]

        distances = examples['distance'].numpy()
        nz = examples['n_intervening'].numpy()
        n_diffs = examples['n_diff_intervening'].numpy()

        actual_verb_indexes = [task.databuilder.sentence_encoder().encode(v)[0] for v in actual_verbs.numpy()]
        #inflected_verb_indexes = [task.databuilder.sentence_encoder().encode(v)[0] for v in inflected_verbs]


        predictions = model(inputs, training=False)
        predictions = np.argmax(predictions, axis=-1)
        corrects = predictions == verb_classes

        for i, c in enumerate(corrects):
            if actual_verb_indexes[i] == 10035 or actual_verb_indexes[i] == 2:
                continue
            if nz[i] > 4 or distances[i] > 16:
                continue

            distance_total[distances[i]] += 1
            distance_hits[distances[i]] += int(c)
            if nz[i] == n_diffs[i]:
                n = nz[i]
                diff_total[n] += 1
                diff_hits[n] += int(c)
    
    return distance_hits, distance_total, diff_hits, diff_total


infl_eng = inflect.engine()
verb_infl, noun_infl = gen_inflect_from_vocab(infl_eng, 'wiki.vocab')

for label,model in zip(student_labels, student_models):
    print(label)
    print(model.model_name)
    print('##################################')
    distance_hits, distance_total, diff_hits, diff_total = evaluate_vp_cl(model, verb_infl, noun_infl, task)
    compute_and_print_acc_stats(distance_hits, distance_total, diff_hits, diff_total)
    break
